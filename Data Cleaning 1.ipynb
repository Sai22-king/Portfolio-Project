# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r"C:\Users\Saikrishna S\OneDrive\Desktop\Waste project\Waste Disposal Practices Survey   (Responses).xlsx")

# %%
df
# Out:
#                   Timestamp                            Name       Age  \
# 0   2025-02-08 14:05:29.731                 PRAVIN KUMAR PR        22
# 1   2025-02-08 14:13:24.963                 Karthik Raja Y         22
# 2   2025-02-08 14:16:26.584                         SURAJ S        22
# 3   2025-02-08 14:22:14.719                           Sujan        21
# 4   2025-02-08 14:40:56.733                Krishna Kumar B         22
# 5   2025-02-08 15:19:04.821                   SARAVANAN P S        49
# 6                       NaT                             NaN       NaN
# 7   2025-02-08 17:09:00.246                  Arun Rajendran        35
# 8   2025-02-08 17:10:20.062                          Venkat        40
# 9   2025-02-08 17:11:36.201                     Naga Suresh        41
# 10  2025-02-08 17:12:42.395         Sivakumar Krishnaprasad        55
# 11  2025-02-08 17:28:35.165                     A.Chezhiyan        52
# ...

# %%
pd.set_option('display.max.rows', 102)
pd.set_option('display.max.columns', 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 32 columns):
#  #   Column                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                          --------------  -----
#  0   Timestamp                                                                                       100 non-null    datetime64[ns]
#  1   Name                                                                                            100 non-null    object
#  2   Age                                                                                             100 non-null    object
#  3   What is your current occupation?                                                                100 non-null    object
#  4   How would you classify the area where you live?                                                 100 non-null    object
# ...

# %%
df1 = df1.copy()

# %%
df1 = df

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
df1 = df.drop(columns = 'Timestamp')
df1
# Out:
#                                Name       Age  \
# 0                   PRAVIN KUMAR PR        22
# 1                   Karthik Raja Y         22
# 2                           SURAJ S        22
# 3                             Sujan        21
# 4                  Krishna Kumar B         22
# 5                     SARAVANAN P S        49
# 6                               NaN       NaN
# 7                    Arun Rajendran        35
# 8                            Venkat        40
# 9                       Naga Suresh        41
# 10          Sivakumar Krishnaprasad        55
# 11                      A.Chezhiyan        52
# 12                       BALAJI DAS        49
# 13   B Arockiaraj Ignatious Gerald         56
# 14                          Venkat         47
# 15                Jayachandra Babu         53
# 16                    Kaunain Ali M        39
# 17                 Chandrasekaran k        44
# 18                  R Govindarajan         68
# ...

# %%
df1 = df1.dropna(how='all')
df1
# Out:
#                                Name       Age  \
# 0                   PRAVIN KUMAR PR        22
# 1                   Karthik Raja Y         22
# 2                           SURAJ S        22
# 3                             Sujan        21
# 4                  Krishna Kumar B         22
# 5                     SARAVANAN P S        49
# 7                    Arun Rajendran        35
# 8                            Venkat        40
# 9                       Naga Suresh        41
# 10          Sivakumar Krishnaprasad        55
# 11                      A.Chezhiyan        52
# 12                       BALAJI DAS        49
# 13   B Arockiaraj Ignatious Gerald         56
# 14                          Venkat         47
# 15                Jayachandra Babu         53
# 16                    Kaunain Ali M        39
# 17                 Chandrasekaran k        44
# 18                  R Govindarajan         68
# 19               Idaya selvan Cyril        35
# ...

# %%
df1.columns
# Out:
# Index(['Name', 'Age', 'What is your current occupation?',
#        'How would you classify the area where you live?  ',
#        'Do you know the difference between dry waste and wet waste?',
#        'How often do you separate dry and wet waste at home?  ',
#        'How do you usually dispose of your household waste?',
#        'Do you segregate your household waste into dry and wet categories?',
#        'If No, what is the main reason you don’t segregate waste?  ',
#        'If Yes, how do you dispose of your segregated waste?  ',
#        'How do you dispose of paper waste?  ',
#        'How do you dispose of plastic waste?  ',
#        'How do you dispose of glass waste?',
#        'How do you dispose of metal waste?  ',
#        'How do you dispose of wood waste?  ',
#        'How do you dispose of rubber waste?  ',
#        'How do you dispose of electronic waste?  ',
#        'How do you dispose of textile waste?  ',
#        'How do you dispose of other dry waste?  ',
# ...

# %%
seg_col = 'Do you segregate your household waste into dry and wet categories?'
no_col = 'If No, what is the main reason you don’t segregate waste?  '
yes_col = 'If Yes, how do you dispose of your segregated waste?  '

# %%
df1.loc[df1[seg_col] == "Yes", no_col] = np.nan
df1.loc[df1[seg_col] == "No", yes_col] = np.nan
# Out:
# D:\R-4.4.2\RTemp\ipykernel_30664\1097129525.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.loc[df1[seg_col] == "Yes", no_col] = np.nan
# D:\R-4.4.2\RTemp\ipykernel_30664\1097129525.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.loc[df1[seg_col] == "No", yes_col] = np.nan

# %%
df1
# Out:
#                                Name       Age  \
# 0                   PRAVIN KUMAR PR        22
# 1                   Karthik Raja Y         22
# 2                           SURAJ S        22
# 3                             Sujan        21
# 4                  Krishna Kumar B         22
# 5                     SARAVANAN P S        49
# 7                    Arun Rajendran        35
# 8                            Venkat        40
# 9                       Naga Suresh        41
# 10          Sivakumar Krishnaprasad        55
# 11                      A.Chezhiyan        52
# 12                       BALAJI DAS        49
# 13   B Arockiaraj Ignatious Gerald         56
# 14                          Venkat         47
# 15                Jayachandra Babu         53
# 16                    Kaunain Ali M        39
# 17                 Chandrasekaran k        44
# 18                  R Govindarajan         68
# 19               Idaya selvan Cyril        35
# ...

# %%
df1["Name"] = df1["Name"].str.title().str.strip()
# Out:
# D:\R-4.4.2\RTemp\ipykernel_30664\3172129474.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Name"] = df1["Name"].str.title().str.strip()

# %%
df1["State"].unique()
# Out:
# array(['Tamil Nadu', 'Andhra Pradesh', 'Delhi', 'Uttrakhand',
#        'Maharashtra', 'Haryana', 'Rajasthan'], dtype=object)

# %%
df1.iloc[42]['State']
# Out:
# 'India'

# %%
df1.iloc[42]
# Out:
# Name                                                                                                                                  Ushanandini.S
# Age                                                                                                                                              53
# What is your current occupation?                                                                                               Employed (full-time)
# How would you classify the area where you live?                                                                                           Mega City
# Do you know the difference between dry waste and wet waste?                                                                                     Yes
# How often do you separate dry and wet waste at home?                                                                                         Always
# ...

# %%
df1['State'] = df1['State'].str.replace(r'Tamilnadu|TAMILNADU|tamilnadu|taminadu|Taminadu|tamilinadu|TAMIL NADU|Tamil nadu|tn|Tn|TN|Chennai|India|No awarness among  women and maid working in most of the house about segregation  of degradable  and non degradable. ','Tamil Nadu',regex = True).str.strip().str.title()
# Out:
# D:\R-4.4.2\RTemp\ipykernel_30664\48235221.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['State'] = df1['State'].str.replace(r'Tamilnadu|TAMILNADU|tamilnadu|taminadu|Taminadu|tamilinadu|TAMIL NADU|Tamil nadu|tn|Tn|TN|Chennai|India|No awarness among  women and maid working in most of the house about segregation  of degradable  and non degradable. ','Tamil Nadu',regex = True).str.strip().str.title()

# %%
df1['State']=df1['State'].str.replace('New Delhi','Delhi')
# Out:
# D:\R-4.4.2\RTemp\ipykernel_30664\4261873711.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['State']=df1['State'].str.replace('New Delhi','Delhi')

# %%
df1["District"].unique()
# Out:
# array(['Viluppuram', 'Chengalpattu', 'Chennai', 'Thiruvallur', 'Guntur',
#        'Kancheepuram', 'South West', 'Dehradun', 'Pune', 'Ambala',
#        'Tiruvallur', 'Tiruchirappalli', 'Theni', 'Virudhunagar', 'Nasik',
#        'Jaipur', 'Chittoor', 'Madurai'], dtype=object)

# %%
df1['District'] = df1['District'].str.replace(r'Chengalpet|Chengleput|Chengelpet|Tamilnadu','Chengalpattu',regex = True).str.strip().str.title()
# Out:
# D:\R-4.4.2\RTemp\ipykernel_30664\4280238285.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['District'] = df1['District'].str.replace(r'Chengalpet|Chengleput|Chengelpet|Tamilnadu','Chengalpattu',regex = True).str.strip().str.title()

# %%
df1['District'] = df1['District'].str.replace(r'Tamil Nadu|Chenai','Chennai', regex = True)
# Out:
# D:\R-4.4.2\RTemp\ipykernel_30664\1798740814.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['District'] = df1['District'].str.replace(r'Tamil Nadu|Chenai','Chennai', regex = True)

# %%
df1['District'] = df1['District'].str.replace('Villupuram','Viluppuram')
# Out:
# D:\R-4.4.2\RTemp\ipykernel_30664\327998307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['District'] = df1['District'].str.replace('Villupuram','Viluppuram')

# %%
df1['District'] = df1['District'].str.replace(r'Kanchipuram|Kanchpueam','Kancheepuram', regex = True)
# Out:
# D:\R-4.4.2\RTemp\ipykernel_30664\3773433429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['District'] = df1['District'].str.replace(r'Kanchipuram|Kanchpueam','Kancheepuram', regex = True)

# %%
df1['District'] = df1['District'].str.replace('Tiruchirapalli','Tiruchirappalli')
# Out:
# D:\R-4.4.2\RTemp\ipykernel_30664\1133821671.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['District'] = df1['District'].str.replace('Tiruchirapalli','Tiruchirappalli')

# %%
df1
# Out:
#                               Name       Age What is your current occupation?  \
# 0                  Pravin Kumar Pr        22                       Unemployed
# 1                   Karthik Raja Y        22                          Student
# 2                          Suraj S        22             Employed (full-time)
# 3                            Sujan        21             Employed (full-time)
# 4                  Krishna Kumar B        22             Employed (full-time)
# 5                    Saravanan P S        49                    Self-employed
# 7                   Arun Rajendran        35             Employed (full-time)
# 8                           Venkat        40             Employed (full-time)
# 9                      Naga Suresh        41             Employed (full-time)
# 10         Sivakumar Krishnaprasad        55                    Self-employed
# 11                     A.Chezhiyan        52             Employed (full-time)
# ...

# %%
df1 = df1.rename(columns = {'What is your current occupation?' : 'Occupation','How would you classify the area where you live?' : 'Area Type',
                     'Do you know the difference between dry waste and wet waste?' : 'Waste Type Awareness','How often do you separate dry and wet waste at home?': 'Frequency of Separating Waste',
                     'How do you usually dispose of your household waste?' : 'Household Waste Disposal','Do you segregate your household waste into dry and wet categories?' : 'Segregation of Household Waste',
                     'If No, what is the main reason you don’t segregate waste?' : 'Reason for not segregating waste','If Yes, how do you dispose of your segregated waste?' : 'Disposal of Segregated Waste',
                     "How do you dispose of paper waste?": "Paper_Waste_Disposal",
                     "How do you dispose of plastic waste?": "Plastic_Waste_Disposal",
                     "How do you dispose of glass waste?": "Glass_Waste_Disposal",
                     "How do you dispose of metal waste?": "Metal_Waste_Disposal",
                     "How do you dispose of wood waste?": "Wood_waste_Disposal",
                     "How do you dispose of rubber waste?": "Rubber_Waste_Disposal",
                     "How do you dispose of electronic waste?": "E_Waste_Disposal",
                     "How do you dispose of textile waste?": "Textile_Waste_Disposal",
                     "How do you dispose of other dry waste?": "Other_Dry_Waste_Disposal",
                     "How do you dispose of food waste?": "Food_Waste_Disposal",
                     "How do you dispose of garden waste?": "Garden_Waste_Disposal",
                     "How do you dispose of dairy and liquid waste?": "Dairy_Liquid_Waste_Disposal",
                     "How do you dispose of other wet waste?": "Other_Wet_Waste_Disposal","What are the biggest challenges you face in segregating waste at home?": "Waste_Segregation_Challenges",
                     "Do you think your neighborhood has proper waste disposal facilities?": "Neighborhood_Waste_Facilities",
                     "How often do you find it difficult to differentiate between dry and wet waste?": "Frequency_of_Difficulty_Differentiating_Waste",
                     "Do you think there is enough awareness about proper waste segregation in your community?": "Community_Awareness_Waste",
                     "Would incentives (like discounts, rewards, or penalties) encourage better waste segregation?": "Incentives_for_Segregation",
                     "What improvements would help you practice better waste segregation?": "Suggested_Improvements"})

# %%
df1.columns = df1.columns.str.strip()

# %%
df1.columns.str.title()
# Out:
# Index(['Name', 'Age', 'Occupation', 'Area Type', 'Waste Type Awareness',
#        'Frequency Of Separating Waste', 'Household Waste Disposal',
#        'Segregation Of Household Waste', 'Reason For Not Segregating Waste',
#        'Disposal Of Segregated Waste', 'Paper_Waste_Disposal',
#        'Plastic_Waste_Disposal', 'Glass_Waste_Disposal',
#        'Metal_Waste_Disposal', 'Wood_Waste_Disposal', 'Rubber_Waste_Disposal',
#        'E_Waste_Disposal', 'Textile_Waste_Disposal',
#        'Other_Dry_Waste_Disposal', 'Food_Waste_Disposal',
#        'Garden_Waste_Disposal', 'Dairy_Liquid_Waste_Disposal',
#        'Other_Wet_Waste_Disposal', 'Waste_Segregation_Challenges',
#        'Neighborhood_Waste_Facilities',
#        'Frequency_Of_Difficulty_Differentiating_Waste',
#        'Community_Awareness_Waste', 'Incentives_For_Segregation',
#        'Suggested_Improvements', 'State', 'District'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Name', 'Age', 'Occupation', 'Area Type', 'Waste Type Awareness',
#        'Frequency of Separating Waste', 'Household Waste Disposal',
#        'Segregation of Household Waste', 'Reason for not segregating waste',
#        'Disposal of Segregated Waste', 'Paper_Waste_Disposal',
#        'Plastic_Waste_Disposal', 'Glass_Waste_Disposal',
#        'Metal_Waste_Disposal', 'Wood_waste_Disposal', 'Rubber_Waste_Disposal',
#        'E_Waste_Disposal', 'Textile_Waste_Disposal',
#        'Other_Dry_Waste_Disposal', 'Food_Waste_Disposal',
#        'Garden_Waste_Disposal', 'Dairy_Liquid_Waste_Disposal',
#        'Other_Wet_Waste_Disposal', 'Waste_Segregation_Challenges',
#        'Neighborhood_Waste_Facilities',
#        'Frequency_of_Difficulty_Differentiating_Waste',
#        'Community_Awareness_Waste', 'Incentives_for_Segregation',
#        'Suggested_Improvements', 'State', 'District'],
#       dtype='object')

# %%
df1['Age']
# Out:
# 0            22
# 1            22
# 2            22
# 3            21
# 4            22
# 5            49
# 7            35
# 8            40
# 9            41
# 10           55
# 11           52
# 12           49
# 13           56
# 14           47
# 15           53
# 16           39
# 17           44
# 18           68
# 19           35
# 20           44
# 21           47
# 22           45
# 23           37
# 24           36
# 25           47
# 26           36
# 27           54
# 28           46
# 29           37
# 30           45
# 31           42
# 32           49
# 33           42
# 34           42
# 35           43
# 36           36
# 37           43
# 38           48
# 39           34
# 40           38
# 41           40
# 42           48
# 43           53
# 44           42
# 45           21
# 46           24
# 47           36
# 48           45
# 49     42 years
# 50           58
# 51           13
# 53           14
# 54           30
# 55           20
# 56           22
# ...

# %%
df1["Age"] = df1["Age"].astype(str).str.replace("years", "").str.strip()

# %%
df1.dtypes
# Out:
# Name                                             object
# Age                                              object
# Occupation                                       object
# Area Type                                        object
# Waste Type Awareness                             object
# Frequency of Separating Waste                    object
# Household Waste Disposal                         object
# Segregation of Household Waste                   object
# Reason for not segregating waste                 object
# Disposal of Segregated Waste                     object
# Paper_Waste_Disposal                             object
# Plastic_Waste_Disposal                           object
# Glass_Waste_Disposal                             object
# Metal_Waste_Disposal                             object
# Wood_waste_Disposal                              object
# Rubber_Waste_Disposal                            object
# E_Waste_Disposal                                 object
# ...

# %%
df1
# Out:
#                               Name Age            Occupation  \
# 0                  Pravin Kumar Pr  22            Unemployed
# 1                   Karthik Raja Y  22               Student
# 2                          Suraj S  22  Employed (full-time)
# 3                            Sujan  21  Employed (full-time)
# 4                  Krishna Kumar B  22  Employed (full-time)
# 5                    Saravanan P S  49         Self-employed
# 7                   Arun Rajendran  35  Employed (full-time)
# 8                           Venkat  40  Employed (full-time)
# 9                      Naga Suresh  41  Employed (full-time)
# 10         Sivakumar Krishnaprasad  55         Self-employed
# 11                     A.Chezhiyan  52  Employed (full-time)
# 12                      Balaji Das  49         Self-employed
# 13   B Arockiaraj Ignatious Gerald  56  Employed (full-time)
# 14                          Venkat  47  Employed (full-time)
# ...

# %%
col = df1.pop("State")  
df1.insert(3, "State", col)

# %%
col = df1.pop("District")  
df1.insert(4, "District", col)

# %%
df1
# Out:
#                               Name Age            Occupation           State  \
# 0                  Pravin Kumar Pr  22            Unemployed      Tamil Nadu
# 1                   Karthik Raja Y  22               Student      Tamil Nadu
# 2                          Suraj S  22  Employed (full-time)      Tamil Nadu
# 3                            Sujan  21  Employed (full-time)      Tamil Nadu
# 4                  Krishna Kumar B  22  Employed (full-time)      Tamil Nadu
# 5                    Saravanan P S  49         Self-employed      Tamil Nadu
# 7                   Arun Rajendran  35  Employed (full-time)      Tamil Nadu
# 8                           Venkat  40  Employed (full-time)      Tamil Nadu
# 9                      Naga Suresh  41  Employed (full-time)  Andhra Pradesh
# 10         Sivakumar Krishnaprasad  55         Self-employed      Tamil Nadu
# 11                     A.Chezhiyan  52  Employed (full-time)      Tamil Nadu
# ...

# %%
df1['Waste_Segregation_Challenges']
# Out:
# 0                  Waste collectors mix the waste anyway
# 1                       Not enough space for segregation
# 2                                      Lack of awareness
# 3                             No separate bins available
# 4      Lack of time and different types of waste accu...
# 5                       Not enough space for segregation
# 7      No separate bins available, Waste collectors m...
# 8      Lack of awareness, No separate bins available,...
# 9      I don't face any challenges; I segregate waste...
# 10                 Waste collectors mix the waste anyway
# 11                 Waste collectors mix the waste anyway
# 12     I don't face any challenges; I segregate waste...
# 13     I don't face any challenges; I segregate waste...
# 14                      Not enough space for segregation
# 15                 Waste collectors mix the waste anyway
# 16                            No separate bins available
# ...

# %%
df1[['Waste_Segregation_Challenges_1','Waste_Segregation_Challenges_2','Waste_Segregation_Challenges_3','Waste_Segregation_Challenges_4']] = df1['Waste_Segregation_Challenges'].str.split(',', n=3, expand = True)

# %%
df1.columns
# Out:
# Index(['Name', 'Age', 'Occupation', 'State', 'District', 'Area Type',
#        'Waste Type Awareness', 'Frequency of Separating Waste',
#        'Household Waste Disposal', 'Segregation of Household Waste',
#        'Reason for not segregating waste', 'Disposal of Segregated Waste',
#        'Paper_Waste_Disposal', 'Plastic_Waste_Disposal',
#        'Glass_Waste_Disposal', 'Metal_Waste_Disposal', 'Wood_waste_Disposal',
#        'Rubber_Waste_Disposal', 'E_Waste_Disposal', 'Textile_Waste_Disposal',
#        'Other_Dry_Waste_Disposal', 'Food_Waste_Disposal',
#        'Garden_Waste_Disposal', 'Dairy_Liquid_Waste_Disposal',
#        'Other_Wet_Waste_Disposal', 'Waste_Segregation_Challenges',
#        'Neighborhood_Waste_Facilities',
#        'Frequency_of_Difficulty_Differentiating_Waste',
#        'Community_Awareness_Waste', 'Incentives_for_Segregation',
#        'Suggested_Improvements'],
#       dtype='object')

# %%
df1
# Out:
#                               Name Age            Occupation           State  \
# 0                  Pravin Kumar Pr  22            Unemployed      Tamil Nadu
# 1                   Karthik Raja Y  22               Student      Tamil Nadu
# 2                          Suraj S  22  Employed (full-time)      Tamil Nadu
# 3                            Sujan  21  Employed (full-time)      Tamil Nadu
# 4                  Krishna Kumar B  22  Employed (full-time)      Tamil Nadu
# 5                    Saravanan P S  49         Self-employed      Tamil Nadu
# 7                   Arun Rajendran  35  Employed (full-time)      Tamil Nadu
# 8                           Venkat  40  Employed (full-time)      Tamil Nadu
# 9                      Naga Suresh  41  Employed (full-time)  Andhra Pradesh
# 10         Sivakumar Krishnaprasad  55         Self-employed      Tamil Nadu
# 11                     A.Chezhiyan  52  Employed (full-time)      Tamil Nadu
# ...

# %%
df1 = df1.drop(columns = 'Waste_Segregation_Challenges')

# %%
df1[['Suggested_Improvements_1','Suggested_Improvements_2','Suggested_Improvements_3','Suggested_Improvements_4']] = df1['Suggested_Improvements'].str.split(',', n=3, expand = True)

# %%
df1.drop(columns = 'Suggested_Improvements')
# Out:
#                               Name Age            Occupation           State  \
# 0                  Pravin Kumar Pr  22            Unemployed      Tamil Nadu
# 1                   Karthik Raja Y  22               Student      Tamil Nadu
# 2                          Suraj S  22  Employed (full-time)      Tamil Nadu
# 3                            Sujan  21  Employed (full-time)      Tamil Nadu
# 4                  Krishna Kumar B  22  Employed (full-time)      Tamil Nadu
# 5                    Saravanan P S  49         Self-employed      Tamil Nadu
# 7                   Arun Rajendran  35  Employed (full-time)      Tamil Nadu
# 8                           Venkat  40  Employed (full-time)      Tamil Nadu
# 9                      Naga Suresh  41  Employed (full-time)  Andhra Pradesh
# 10         Sivakumar Krishnaprasad  55         Self-employed      Tamil Nadu
# 11                     A.Chezhiyan  52  Employed (full-time)      Tamil Nadu
# ...

# %%
df1.to_excel('Waste.xlsx', index=False)

# %%
df1 = df1.fillna('')

# %%
df1["Age"] = df1["Age"].astype(int)

# %%
df1
# Out:
#                               Name Age            Occupation           State  \
# 0                  Pravin Kumar Pr  22            Unemployed      Tamil Nadu
# 1                   Karthik Raja Y  22               Student      Tamil Nadu
# 2                          Suraj S  22  Employed (full-time)      Tamil Nadu
# 3                            Sujan  21  Employed (full-time)      Tamil Nadu
# 4                  Krishna Kumar B  22  Employed (full-time)      Tamil Nadu
# 5                    Saravanan P S  49         Self-employed      Tamil Nadu
# 7                   Arun Rajendran  35  Employed (full-time)      Tamil Nadu
# 8                           Venkat  40  Employed (full-time)      Tamil Nadu
# 9                      Naga Suresh  41  Employed (full-time)  Andhra Pradesh
# 10         Sivakumar Krishnaprasad  55         Self-employed      Tamil Nadu
# 11                     A.Chezhiyan  52  Employed (full-time)      Tamil Nadu
# ...

# %%
df1.dtypes
# Out:
# Name                                             object
# Age                                               int32
# Occupation                                       object
# State                                            object
# District                                         object
# Area Type                                        object
# Waste Type Awareness                             object
# Frequency of Separating Waste                    object
# Household Waste Disposal                         object
# Segregation of Household Waste                   object
# Reason for not segregating waste                 object
# Disposal of Segregated Waste                     object
# Paper_Waste_Disposal                             object
# Plastic_Waste_Disposal                           object
# Glass_Waste_Disposal                             object
# Metal_Waste_Disposal                             object
# Wood_waste_Disposal                              object
# ...

# %%
df1['Age']
# Out:
# 0      22
# 1      22
# 2      22
# 3      21
# 4      22
# 5      49
# 7      35
# 8      40
# 9      41
# 10     55
# 11     52
# 12     49
# 13     56
# 14     47
# 15     53
# 16     39
# 17     44
# 18     68
# 19     35
# 20     44
# 21     47
# 22     45
# 23     37
# 24     36
# 25     47
# 26     36
# 27     54
# 28     46
# 29     37
# 30     45
# 31     42
# 32     49
# 33     42
# 34     42
# 35     43
# 36     36
# 37     43
# 38     48
# 39     34
# 40     38
# 41     40
# 42     48
# 43     53
# 44     42
# 45     21
# 46     24
# 47     36
# 48     45
# 49     42
# 50     58
# 51     13
# 53     14
# 54     30
# 55     20
# 56     22
# 57     21
# 58     22
# 59     22
# 60     22
# 61     18
# 62     34
# 63     23
# 64     18
# 65     21
# 66     18
# 67     36
# 68     22
# 69     19
# 70     15
# 71     21
# 72     20
# 73     25
# 74     48
# 75     50
# 76     47
# 77     49
# 78     21
# 79     21
# 80     31
# 81     49
# 82     42
# 83     25
# 84     54
# ...
