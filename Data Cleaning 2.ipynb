# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"C:\Users\Saikrishna S\OneDrive\Desktop\Waste Disposal Practices.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.read_excel(r"C:\Users\Saikrishna S\OneDrive\Desktop\Waste Disposal Practices.xlsx",sheet_name = ["Dry Waste"])
#
# File D:\New folder\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
# ...

# %%
df
# Out:
#                              Name  Age            Occupation           State  \
# 0                 Pravin Kumar Pr   22            Unemployed      Tamil Nadu
# 1                  Karthik Raja Y   22               Student      Tamil Nadu
# 2                         Suraj S   22  Employed (full-time)      Tamil Nadu
# 3                           Sujan   21  Employed (full-time)      Tamil Nadu
# 4                 Krishna Kumar B   22  Employed (full-time)      Tamil Nadu
# 5                   Saravanan P S   49         Self-employed      Tamil Nadu
# 6                  Arun Rajendran   35  Employed (full-time)      Tamil Nadu
# 7                          Venkat   40  Employed (full-time)      Tamil Nadu
# 8                     Naga Suresh   41  Employed (full-time)  Andhra Pradesh
# 9         Sivakumar Krishnaprasad   55         Self-employed      Tamil Nadu
# 10                    A.Chezhiyan   52  Employed (full-time)      Tamil Nadu
# ...

# %%
pd.set_option('display.max.rows', 100)
pd.set_option('display.max.columns', 40)

# %%
df = df.drop(columns = 'Suggested_Improvements')

# %%
df['Household Waste Disposal'].unique()
# Out:
# array(['I mix dry and wet waste together', 'I separate dry and wet waste',
#        "I don't pay attention to it"], dtype=object)

# %%
df['Household Waste Disposal'] = df['Household Waste Disposal'].replace({"I mix dry and wet waste together" : "Mix Dry and Wet Waste" ,
                                            "I separate dry and wet waste" : "Separate Dry and Wet Waste",
                                            "I don't pay attention to it" : "Don't Pay Attention"})

# %%
df['Reason for not segregating waste']
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2                       Lack of awareness, Lack of time
# 3                                          Lack of time
# 4                                                   NaN
# 5                                                   NaN
# 6                                          Lack of time
# 7          No proper waste collection system in my area
# 8                                                   NaN
# 9          No proper waste collection system in my area
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14         No proper waste collection system in my area
# 15         No proper waste collection system in my area
# 16                                                  NaN
# ...

# %%
df['Disposal of Segregated Waste']
# Out:
# 0     I hand it over to muncipal waste collectors, I...
# 1           I hand it over to muncipal waste collectors
# 2                                                   NaN
# 3                                                   NaN
# 4           I hand it over to muncipal waste collectors
# 5           I hand it over to muncipal waste collectors
# 6                                                   NaN
# 7                                                   NaN
# 8           I hand it over to muncipal waste collectors
# 9                                                   NaN
# 10          I hand it over to muncipal waste collectors
# 11          I hand it over to muncipal waste collectors
# 12          I hand it over to muncipal waste collectors
# 13          I hand it over to muncipal waste collectors
# 14                                                  NaN
# 15                                                  NaN
# 16    We deployed a separate vendor , who is registe...
# ...

# %%
df['E_Waste_Disposal'].unique()
# Out:
# array(['I store it at home, unsure of how to dispose of it',
#        'I give it to an authorized e-waste collector',
#        'I give it to a recycler',
#        'I throw it in the trash (mixed with wet waste)',
#        'I throw it in the trash (in a separate dry waste bin)'],
#       dtype=object)

# %%
df['Dairy_Liquid_Waste_Disposal'].unique()
# Out:
# array(['I give it for municipal composting or bio-gas',
#        'I throw them in the trash (mixed with dry waste)',
#        'I throw them in the trash (in a separate wet waste bin)',
#        'I pour it down the drain', 'I compost it at home (if possible)'],
#       dtype=object)

# %%
mapping = {
    "I throw it in the trash (in a separate dry waste bin)": "Dispose in Dry Waste Bin",
    "I throw them in the trash (in a separate dry waste bin)":"Dispose in Dry Waste Bin",
    "I give it to a recycler": "Give to Recycler",
    "I sell it to a scrap vendor": "Sell to Scrap Vendor",
    "I throw it in the trash (mixed with wet waste)": "Dispose in Mixed Waste Bin",
    "I reuse it for other purposes": "Reuse at Home",
    "I throw them in the trash (in a separate wet waste bin)" : "Dispose in Wet Waste Bin",
    "I throw them in the trash (mixed with wet waste)" : "Dispose in Mixed Waste Bin",
    "I throw them in the trash (mixed with dry waste)" : "Dispose in Mixed Waste Bin",
    "I give it for municipal composting or bio-gas" : "Give for Municipal Composting or Bio-gas",
    "I compost it at home (if possible)" : "Compost at Home",
    "I give it to an authorized e-waste collector" : "Give to E-Waste Collector",
    "I donate usable clothes to charities" : "Donate Usable Clothes to Charities",
    "I pour it down the drain" : "Pour Down the Drain",
    "I sell them to a vendor" : "Sell to Vendor",
    "I store it at home, unsure of how to dispose of it" : "Store at Home"
}

# %%
df1 = df.replace(mapping)

# %%
df1
# Out:
#                              Name  Age            Occupation           State  \
# 0                 Pravin Kumar Pr   22            Unemployed      Tamil Nadu
# 1                  Karthik Raja Y   22               Student      Tamil Nadu
# 2                         Suraj S   22  Employed (full-time)      Tamil Nadu
# 3                           Sujan   21  Employed (full-time)      Tamil Nadu
# 4                 Krishna Kumar B   22  Employed (full-time)      Tamil Nadu
# 5                   Saravanan P S   49         Self-employed      Tamil Nadu
# 6                  Arun Rajendran   35  Employed (full-time)      Tamil Nadu
# 7                          Venkat   40  Employed (full-time)      Tamil Nadu
# 8                     Naga Suresh   41  Employed (full-time)  Andhra Pradesh
# 9         Sivakumar Krishnaprasad   55         Self-employed      Tamil Nadu
# 10                    A.Chezhiyan   52  Employed (full-time)      Tamil Nadu
# ...

# %%
df1["Community_Awareness_Waste"].unique()
# Out:
# array(['Some people know but do not follow them',
#        'No, people are unaware or uninterested',
#        'Yes, most people follow segregation rules'], dtype=object)

# %%
df1["Incentives_for_Segregation"].unique()
# Out:
# array(['No, awareness is more important', 'Not sure',
#        'Yes, it would motivate people'], dtype=object)

# %%
df1["Reason for not Segregating Waste"].unique()
# Out:
# array([nan, 'Lack of awareness, Lack of time', 'Lack of time',
#        'No proper waste collection system in my area',
#        "I don't think it's necessary",
#        "Delhiets don't believe in this as even if it's segregated then it's not collected separately",
#        'Lack of awareness',
#        'Lack of time, No proper waste collection system in my area',
#        'Lack of awareness, Lack of time, No proper waste collection system in my area'],
#       dtype=object)

# %%
df1["Waste_Segregation_Challenges_1"].unique()
# Out:
# array(['Waste collectors mix the waste anyway',
#        'Not enough space for segregation', 'Lack of awareness',
#        'No separate bins available',
#        'Lack of time and different types of waste accumulated at the short time itself ',
#        "I don't face any challenges; I segregate waste properly.",
#        'We have three bins in our community for wet dry and others ',
#        'We segregate food items and peeled vegetables to cattles feeding'],
#       dtype=object)

# %%
df1 = df1.rename(columns={"Reason for not segregating waste": "Reason for not Segregating Waste"})

# %%
df1 = df1.rename(columns={"Frequency of Separating Waste" : "Waste Separation Frequency","Paper_Waste_Disposal" : "Paper Waste Disposal","Plastic_Waste_Disposal" : "Plastic Waste Disposal",
                   "Glass_Waste_Disposal" : "Glass Waste Disposal","Metal_Waste_Disposal" : "Metal Waste Disposal",
                   "Wood_waste_Disposal" : "Wood Waste Disposal","Rubber_Waste_Disposal" : "Rubber Waste Disposal",
                   "E_Waste_Disposal" : "E-Waste Disposal","Textile_Waste_Disposal" : "Textile Waste Disposal",
                   "Other_Dry_Waste_Disposal" : "Other Dry Waste Disposal","Food_Waste_Disposal" : "Food Waste Disposal",
                   "Garden_Waste_Disposal" : "Garden Waste Disposal", "Dairy_Liquid_Waste_Disposal" : "Dairy & Liquid Waste Disposal",
                   "Other_Wet_Waste_Disposal" : "Other Wet Waste Disposal","Neighborhood_Waste_Facilities" : "Neighborhood Waste Facilities",
                   "Frequency_of_Difficulty_Differentiating_Waste" : "Waste Sorting Difficulty Frequency","Community_Awareness_Waste" : "Community Waste Awareness",
                   "Incentives_for_Segregation" : "Segregation Incentives","Waste_Segregation_Challenges_1" : "Waste Segregation Challenge 1",
                    "Waste_Segregation_Challenges_2" : "Waste Segregation Challenge 2",
                    "Waste_Segregation_Challenges_3" : "Waste Segregation Challenge 3",
                    "Waste_Segregation_Challenges_4" : "Waste Segregation Challenge 4",
                    "Suggested_Improvements_1" : "Suggested Improvement 1","Suggested_Improvements_2" : "Suggested Improvement 2",
                    "Suggested_Improvements_3" : "Suggested Improvement 3","Suggested_Improvements_4" : "Suggested Improvement 4"
                   })

# %%
df1[["Waste Segregation Barrier 1","Waste Segregation Barrier 2","Waste Segregation Barrier 3"]] = df1["Reason for not Segregating Waste"].str.split(',',n = 2,expand = True)

# %%
df1[["Segregated Waste Disposal Method 1","Segregated Waste Disposal Method 2"]] = df1["Disposal of Segregated Waste"].str.split(',',n = 1,expand = True)

# %%
df1 = df1.drop(columns = {"Reason for not Segregating Waste","Disposal of Segregated Waste"})

# %%
df1 = df1.fillna('')

# %%
df1.to_excel('Survey Disposal.xlsx', index=False)

# %%
df1
# Out:
#                              Name  Age            Occupation           State  \
# 0                 Pravin Kumar Pr   22            Unemployed      Tamil Nadu
# 1                  Karthik Raja Y   22               Student      Tamil Nadu
# 2                         Suraj S   22  Employed (full-time)      Tamil Nadu
# 3                           Sujan   21  Employed (full-time)      Tamil Nadu
# 4                 Krishna Kumar B   22  Employed (full-time)      Tamil Nadu
# 5                   Saravanan P S   49         Self-employed      Tamil Nadu
# 6                  Arun Rajendran   35  Employed (full-time)      Tamil Nadu
# 7                          Venkat   40  Employed (full-time)      Tamil Nadu
# 8                     Naga Suresh   41  Employed (full-time)  Andhra Pradesh
# 9         Sivakumar Krishnaprasad   55         Self-employed      Tamil Nadu
# 10                    A.Chezhiyan   52  Employed (full-time)      Tamil Nadu
# ...

# %%
df1
# Out:
#                              Name  Age            Occupation           State  \
# 0                 Pravin Kumar Pr   22            Unemployed      Tamil Nadu
# 1                  Karthik Raja Y   22               Student      Tamil Nadu
# 2                         Suraj S   22  Employed (full-time)      Tamil Nadu
# 3                           Sujan   21  Employed (full-time)      Tamil Nadu
# 4                 Krishna Kumar B   22  Employed (full-time)      Tamil Nadu
# 5                   Saravanan P S   49         Self-employed      Tamil Nadu
# 6                  Arun Rajendran   35  Employed (full-time)      Tamil Nadu
# 7                          Venkat   40  Employed (full-time)      Tamil Nadu
# 8                     Naga Suresh   41  Employed (full-time)  Andhra Pradesh
# 9         Sivakumar Krishnaprasad   55         Self-employed      Tamil Nadu
# 10                    A.Chezhiyan   52  Employed (full-time)      Tamil Nadu
# ...

# %%
new = ["Name","Age","State","District","Area Type","Waste Type Awareness","Waste Separation Frequency","Household Waste Disposal","Segregation of Household Waste",
      "Neighborhood Waste Facilities","Waste Sorting Difficulty Frequency","Community Waste Awareness","Segregation Incentives","Waste Segregation Challenge 1","Waste Segregation Challenge 2",
      "Waste Segregation Challenge 3","Waste Segregation Challenge 4","Suggested Improvement 1","Suggested Improvement 2","Suggested Improvement 3","Suggested Improvement 4",
      "Waste Segregation Barrier 1","Waste Segregation Barrier 2","Waste Segregation Barrier 3","Segregated Waste Disposal Method 1","Segregated Waste Disposal Method 2"]

# %%
df2 = df1[new].copy()

# %%
df1
# Out:
#                              Name  Age            Occupation           State  \
# 0                 Pravin Kumar Pr   22            Unemployed      Tamil Nadu
# 1                  Karthik Raja Y   22               Student      Tamil Nadu
# 2                         Suraj S   22  Employed (full-time)      Tamil Nadu
# 3                           Sujan   21  Employed (full-time)      Tamil Nadu
# 4                 Krishna Kumar B   22  Employed (full-time)      Tamil Nadu
# 5                   Saravanan P S   49         Self-employed      Tamil Nadu
# 6                  Arun Rajendran   35  Employed (full-time)      Tamil Nadu
# 7                          Venkat   40  Employed (full-time)      Tamil Nadu
# 8                     Naga Suresh   41  Employed (full-time)  Andhra Pradesh
# 9         Sivakumar Krishnaprasad   55         Self-employed      Tamil Nadu
# 10                    A.Chezhiyan   52  Employed (full-time)      Tamil Nadu
# ...

# %%
df2.to_excel('w.xlsx', index=False)

# %%
new1 = ["Name","Age","State","District","Area Type","Paper Waste Disposal","Plastic Waste Disposal","Glass Waste Disposal","Metal Waste Disposal","Wood Waste Disposal","Rubber Waste Disposal","E-Waste Disposal","Textile Waste Disposal","Other Dry Waste Disposal"]

# %%
df3 = df1[new1].copy()

# %%
df3.to_excel('ww.xlsx',index=False)

# %%
new2 = ["Name","Age","State","District","Area Type","Food Waste Disposal","Garden Waste Disposal","Dairy & Liquid Waste Disposal","Other Wet Waste Disposal"]

# %%
df4 = df1[new2].copy()

# %%
df4.to_excel('www.xlsx',index=False)

# %%
df4
# Out:
#                              Name  Age           State         District  \
# 0                 Pravin Kumar Pr   22      Tamil Nadu       Viluppuram
# 1                  Karthik Raja Y   22      Tamil Nadu     Chengalpattu
# 2                         Suraj S   22      Tamil Nadu          Chennai
# 3                           Sujan   21      Tamil Nadu          Chennai
# 4                 Krishna Kumar B   22      Tamil Nadu      Thiruvallur
# 5                   Saravanan P S   49      Tamil Nadu     Chengalpattu
# 6                  Arun Rajendran   35      Tamil Nadu          Chennai
# 7                          Venkat   40      Tamil Nadu          Chennai
# 8                     Naga Suresh   41  Andhra Pradesh           Guntur
# 9         Sivakumar Krishnaprasad   55      Tamil Nadu          Chennai
# 10                    A.Chezhiyan   52      Tamil Nadu     Chengalpattu
# 11                     Balaji Das   49      Tamil Nadu     Chengalpattu
# ...
